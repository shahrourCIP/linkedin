# %%
import numpy as np
import openpyxl
import pandas as pd
import datetime
import requests
from bs4 import BeautifulSoup
from itertools import zip_longest


import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#THIS LOCAL FILE WORKS PERFECTLY. I HAVE 12,000 HTML FILES IN THIS DIRECTORY TO PROCESS.  HOW?
my_url = 'file:Abdalrahman Shahrour _ LinkedIn.html'

uClient = uReq(my_url)
page_html = uClient.read()
# html parsing
page_soup = soup(page_html, "html.parser")

# %%
page_soup
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0037)https://www.linkedin.com/in/shahrour/ -->
# <html class="theme theme--mercado artdeco windows" lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script async="" charset="utf-8" id="utag_129" src="./Abdalrahman Shahrour _ LinkedIn_files/gtag-adwords.js.download" type="text/javascript"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Abdalrahman Shahrour | LinkedIn</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/lxvezhyg37pr01ya2napewka" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# ...

# %%
# grabs each field
contactname = page_soup.findAll("td", {"itemprop": "name"})

# %%
# id="ember229"
name = page_soup.findAll("div", {"class": "artdeco-entity-lockup__title ember-view"})

# %%
name[0].text
# Out:
# '\n        Abdalrahman Shahrour\n\n'

# %%
Head = page_soup.findAll("div", {"class": "artdeco-entity-lockup__subtitle ember-view truncate"})

# %%
print(Head[0].text)
# Out:
#         AI Engineer | Data Scientist | Full Stack Python Developer | ZUJ AI Graduate

# %%
About = page_soup.findAll("div", {"class": "pv-shared-text-with-see-more full-width t-14 t-normal t-black display-flex align-items-center"})

# %%
print(About[2].text)
# Out:
# • Developed a specialized library for natural language processing in Python, focusing on Arabic language processing.• Utilized machine learning and deep learning techniques to analyze and process Arabic text data.• Gained experience in data preprocessing, text tokenization, feature extraction, and sentiment analysis.• Implemented NLP techniques such as stemming, lemmatization, and part-of-speech tagging to enhance the library's accuracy and efficiency.• Demonstrates strong technical skills in Python programming and NLP techniques.• Developed solutions that meet specific industry needs.• Showcase of technical expertise and collaboration skills.• Developed a specialized library for natural language processing in Python, focusing on Arabic language processing.
# • Utilized machine learning and deep learning techniques to analyze and process Arabic text data.
# • Gained experience in data preprocessing, text tokenization, feature extraction, and sentiment analysis.
# ...

# %%
ex = page_soup.findAll("div", {"class": ""})

# %%
print(ex[1].text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Creator modeCreator mode
#
#
# OffOff
#
#
#
# Get discovered, showcase content on your profile, and get access to creator toolsGet discovered, showcase content on your profile, and get access to creator tools
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# My networkMy network
#
#
#
# See and manage your connections and interests.See and manage your connections and interests.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Show all 5 resources
